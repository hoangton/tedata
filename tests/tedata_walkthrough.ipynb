# %%
import sys
import os
import pandas as pd
from pprint import pprint
import tedata as ted
# Out:
# INFO - tedata package initialized successfully!

# %% [markdown]
# # tedata package
# Download data from Trading Economics. There are several ways to use this package.
# # Approach #1: search for indicators and then download the data for a given search result.
# ## Initialise new search_TE object.
# Object will use an existing webdriver if there is already more than one active in the namespace when use_existing_driver=True.
# This will save you some time and be more memory efficient.

# %%
search = ted.search_TE(use_existing_driver=False, headless=False)  # Will open firefox browser window as headless=False.
# Out:
# INFO - New firefox webdriver created.
# INFO - Loading home page at https://tradingeconomics.com/ ...
# INFO - Home page at https://tradingeconomics.com loaded successfully! Search box element found.

# %% [markdown]
# ### Use the search_trading_economics method to use the search bar on the homepage to search.

# %%
search.search_trading_economics("high yield spread", wait_time=5) # Set wait_time to a higher value if you get an empty results table. Default is 5s.
search.result_table.head(6)
# Out:
# INFO - Clicking search box...
# INFO - Entering search term: high yield spread
# INFO - Submitting search, waiting 5s for page to load...
# Found search results on page.
#               country                                             metric  \
# result
# 0       united states  bofa merrill lynch us high yield option adjust...
# 1       united states  bofa merrill lynch private sector issuers us e...
# 2       united states  bofa merrill lynch high yield emerging markets...
# 3       united states  bofa merrill lynch us high yield ccc or below ...
# 4       united states  bofa merrill lynch high yield us emerging mark...
# 5       united states  bofa merrill lynch us high yield bb option adj...
# 6       united states  bofa merrill lynch us high yield b option adju...
#
#                                                       url
# result
# 0       https://tradingeconomics.com/united-states/bof...
# 1       https://tradingeconomics.com/united-states/bof...
# 2       https://tradingeconomics.com/united-states/bof...
# 3       https://tradingeconomics.com/united-states/bof...
# 4       https://tradingeconomics.com/united-states/bof...
# 5       https://tradingeconomics.com/united-states/bof...
# 6       https://tradingeconomics.com/united-states/bof...

# %% [markdown]
# ### Download the time-series for a particular indicator using a search result displayed in your search results table.
#
# Sometimes you may get an error straight away on the first run of the ```get_data``` method. Error message will be something about error establising a connection.
#
# Noted error messages for this:
# - Error loading page: Message: Failed to write request to stream
# - Error loading page: Message: Tried to run command without establishing a connection
#
# Just try again if so, it has always worked for me the second time unless internet connection is down or too slow.

# %%
scraped = search.get_data(0)  ## Using result number 5 in result_table attribute.
# Sometimes you may get an error straight away on the first run of this method. Error message about error establising connection.
# Just try again if so, it has always worked for me the second time unless internet connection is down or too slow
# Out:
# INFO - scrape_chart function: Scraping chart at: https://tradingeconomics.com/united-states/bofa-merrill-lynch-us-high-yield-option-adjusted-spread-fed-data.html, time: 2025-03-21 10:36:59.814510, method: highcharts_api
# Attempting to scrape data for result  0 ,  united states bofa merrill lynch us high yield option adjusted spread fed data.html
# Scraping data from: https://tradingeconomics.com/united-states/bofa-merrill-lynch-us-high-yield-option-adjusted-spread-fed-data.html
# INFO - Chart types dictionary created successfully: dict_keys(['Column', 'Spline', 'Areaspline', 'Stepline', 'Line', 'Area'])
# INFO - Chart types dictionary created successfully.
# INFO - Date span set to: 1M
# INFO -
# Series metadata:
#  {'units': '%', 'original_source': 'Federal Reserve of St. Louis', 'title': 'United States - ICE BofA US High Yield Index Option-Adjusted Spread - 2025 Data  2026 Forecast 1996 Historical', 'indicator': 'bofa merrill lynch us high yield option adjusted spread fed data.html', 'country': 'united states', 'source': 'Trading Economics', 'id': 'united-states/bofa-merrill-lynch-us-high-yield-option-adjusted-spread-fed-data.html'}
# Description card not found:  {"'NoneType' object has no attribute 'select_one'"}
# INFO - Date span set to custom range: 1850-01-01 to 2025-03-21 (using JavaScript)
# INFO - Successfully extracted series data from Highcharts.
# INFO - Successfully scraped series from Highcharts API.
# Data scraped successfully from: https://tradingeconomics.com/united-states/bofa-merrill-lynch-us-high-yield-option-adjusted-spread-fed-data.html

# %% [markdown]
# ### Plot your downloaded series using plotly to create an interactive chart with tooltips.

# %%
scraped.plot_series(ann_box_pos=(0, -0.23))  # Yu can move the annotation box around by changing the values of ann_box_pos.

# %%
scraped.save_plot(format="html")  #Export static plot as png if you wish. Use format="html" for interactive plot export.

# %%
scraped.metadata  #View the metadata for the series.
# Out:
# {'units': '%',
#  'original_source': 'Federal Reserve of St. Louis',
#  'title': 'United States - ICE BofA US High Yield Index Option-Adjusted Spread - 2025 Data  2026 Forecast 1996 Historical',
#  'indicator': 'bofa merrill lynch us high yield option adjusted spread fed data.html',
#  'country': 'united states',
#  'source': 'Trading Economics',
#  'id': 'united-states/bofa-merrill-lynch-us-high-yield-option-adjusted-spread-fed-data.html',
#  'frequency': 'Unknown/irregular',
#  'start_date': '1996-12-31',
#  'end_date': '2025-03-18',
#  'min_value': 2.41,
#  'max_value': 21.82,
#  'length': 7365}

# %% [markdown]
# # Approach #2: Download data for a given Indicator + Country combination or a given URL with a single line.
#
# Sometimes you may get an error straight away on the first run of the ```scrape_chart``` method. Error message will be something about error establising a connection.
#
# Noted error messages for this:
# - Error loading page: Message: Failed to write request to stream
# - Error loading page: Message: Tried to run command without establishing a connection
#
# Just try again if so, it has always worked for me the second time unless internet connection is down or too slow.
#
# - There is another less common error that can occur which is that the chart type fails to be set to "spline"or "line" prior to a tooltip operation. Tooltip scrapes will fail if the chart type is not one of those. Run the command again and it may well work the second or third time.
# - Use the line below periodically to clean up TE_Scraper and webdriver objects that are still running.

# %%
ted.find_active_drivers(close_all_drivers=True, close__all_scrapers=True)  # Use this to find and quit all active drivers, use it now and then to clean up..
# Out:
# INFO - Closing 2 active TE_Scraper instances...
# INFO - Closing TE_Scraper instance
# INFO - Scraper resources successfully released
# INFO - Closing TE_Scraper instance
# INFO - Scraper resources successfully released
# INFO - Quitting 2 active webdriver instances...
# INFO - Quitting driver (age: 1987.2s)
# INFO - Quitting driver (age: 9824.9s)
# {'Active webdrivers': [], 'Active TE_Scrapers': []}

# %% [markdown]
# #### Single line for data download

# %%
scraped = ted.scrape_chart(country="united-states", indicator = "unemployment", use_existing_driver=False, headless=False) ## Using chart id from the url only, country is "united-states" by default.
# Out:
# INFO - New firefox webdriver created.
# INFO - scrape_chart function: Scraping chart at: https://tradingeconomics.com/united-states/gdp-growth, time: 2025-03-21 13:20:51.603314, method: highcharts_api
# INFO - Chart types dictionary created successfully: dict_keys(['Column', 'Spline', 'Areaspline', 'Stepline', 'Line', 'Area'])
# INFO - Chart types dictionary created successfully.
# INFO - Date span set to: 3Y
# INFO -
# Series metadata:
#  {'units': '%', 'original_source': 'U.S. Bureau of Economic Analysis', 'title': 'United States GDP Growth Rate', 'indicator': 'gdp growth', 'country': 'united states', 'source': 'Trading Economics', 'id': 'united-states/gdp-growth'}
# INFO - Date span set to custom range: 1850-01-01 to 2025-03-21 (using JavaScript)
# INFO - Successfully extracted series data from Highcharts.
# INFO - Successfully scraped series from Highcharts API.

# %%
scraped.plot_series()   #Plotting the series

# %% [markdown]
# ## Overview of different scraping methods that can be used by the ```scrape_chart``` function.
#
# ```scrape_chart()```has the keyword argument 'method' with the possible values of "path", "tooltips", "mixed" or "highcharts_api". *The default is "highcharts_api"*.
# - The "path" method takes the path element for the data series trace from the svg chart. It then scales the pixel co-ordinates using the Y-axis values
# - "tooltips" takes the data values frm the tooltips which show up as the cursor is dragged across the chart. This method may end up with holes in your data if there are many datapoints in the series.
# - "mixed" uses a combination of the two approaches and scrapes all of the data-points from the tooltips in multiple runs. This method should yield the highest accuracy.
# - "highcharts api" takes the series data directly from the highcharts api active on the page. This method was discovered in v0.3.3 and *is the fastest and most accurate*. If this method works for the series you are trying to get, it should always be used. This has been made the default from v0.3.3.
# - If the "highcharts api" method does not work for you give the other methods a try. These other methods may also work on other sites that do not have the highcharts api active. Code modificatin would be necessary though.

# %% [markdown]
# ### Aside note
# - I've found some series have changing frequency over time. e.g a series may have been collected quarterly in the early days and now is collected monthly. For these cases "path" method will not work well at all. To begin to counter this I've created the ```get_earliest_points``` method. **This issue is still not solved as of v0.3.0.**
# - For such cases you can always use the "highcharts_api", "tooltips" or "mixed" methods, which will collect all datapoints from either highcharts object or the tooltips, getting whatever data is actually there.
# - If a series changes frequency and the tooltips do not display values, only "highcharts_api" option could work.
# - ```"highcharts_api"``` option is totally superior for almost all cases and is the fastest.

# %%
scraped.get_earliest_points()
# Get the values of the series for the first 10 years of data.
# Out:
# INFO - Date span set to custom range: 1947-04-01 to 1957-04-01 (using JavaScript)
# INFO - Chart type set to: Spline (using JavaScript)
# INFO - Time taken to select chart type: 0.8619923810038017
# INFO - Time taken to execute JS code: 4.342519253994396
# 1947-04-01    -1.0
# 1947-07-01    -0.8
# 1947-10-01     6.4
# 1948-01-01     6.2
# 1948-04-01     6.8
# 1948-07-01     2.3
# 1948-10-01     0.5
# 1949-01-01    -5.4
# 1949-04-01    -1.4
# 1949-07-01     4.2
# 1949-10-01    -3.3
# 1950-01-01    16.7
# 1950-04-01    12.7
# 1950-07-01    16.4
# 1950-10-01     7.9
# 1951-01-01     5.5
# 1951-04-01     7.1
# 1951-07-01     8.5
# 1951-10-01     0.9
# 1952-01-01     4.3
# 1952-04-01     0.8
# 1952-07-01     2.9
# 1952-10-01    13.8
# 1953-01-01     7.7
# 1953-04-01     3.1
# 1953-07-01    -2.2
# 1953-10-01    -5.9
# 1954-01-01    -1.9
# 1954-04-01     0.4
# 1954-07-01     4.6
# 1954-10-01     8.1
# 1955-01-01    11.9
# 1955-04-01     6.7
# 1955-07-01     5.5
# 1955-10-01     2.4
# 1956-01-01    -1.5
# 1956-04-01     3.3
# 1956-07-01    -0.3
# 1956-10-01     6.8
# 1957-01-01     2.6
# Name: United States GDP Growth Rate, dtype: float64

# %% [markdown]
# # Approach #3: Debug method - manually run through the steps.
#
# - Below is an example of the manual implementation of the "path" method.
#
# If you get an error on trying load_page method, something like the examples below:
# - Error loading page: Message: Failed to decode response from marionette
# - Error loading page: Message: Tried to run command without establishing a connection
#
# You need to start a new webdriver instance. Reinitilize your TE_Scraper object and set: ```use_existing_driver = False```

# %%
scr = ted.TE_Scraper(use_existing_driver=False, headless = False)  ## Initialize a new TE_scraper object.
# Out:
# INFO - New firefox webdriver created.

# %%
scr.load_page('https://tradingeconomics.com/united-states/personal-income', extra_wait_time=4) ## Load a new page containing chart. Use higher extra_wait_time if it fails.
#"https://tradingeconomics.com/united-states/personal-income" https://tradingeconomics.com/united-states/manufacturing-pmi
# Out:
# INFO - Chart types dictionary created successfully: dict_keys(['Column', 'Spline', 'Areaspline', 'Stepline', 'Line', 'Area'])
# INFO - Date span set to: 1Y
# True

# %%
scr.scrape_metadata() ## Scrape the metadata for the data series from the page.
# Out:
# INFO -
# Series metadata:
#  {'units': '%', 'original_source': 'U.S. Bureau of Economic Analysis', 'title': 'United States Personal Income', 'indicator': 'personal income', 'country': 'united states', 'source': 'Trading Economics', 'id': 'united-states/personal-income'}

# %%
scr.make_x_index() ## Create the x_index for the series first.
# Out:
# INFO - Chart type set to: Spline (using JavaScript)
# Using selenium and tooltip scraping to construct the date time index for the time-series, this'll take a bit...
# INFO - Time taken to select chart type: 0.717258695003693
# INFO - Time taken to execute JS code: 19.61975732800056
# Frequency of time-series:  MS
# INFO - Date span set to custom range: 1850-01-01 to 2025-03-14 (using JavaScript)
# INFO - Chart type set to: Spline (using JavaScript)
# INFO - Successfully retrieved first/last dates.
# Converted end_date: 2025-01-01 00:00:00
# Retrying start_end extraction...
# INFO - Successfully retrieved first/last dates.
# INFO - Start and end values scraped from tooltips:
# {'end_date': Timestamp('2025-01-01 00:00:00'), 'end_value': 0.9, 'start_date': Timestamp('1959-02-01 00:00:00'), 'start_value': 0.5, 'unit_str': '%'}
# INFO - DateTimeIndex created successfully for the time-series.
# Converted start_date: 1959-02-01 00:00:00
# Converted end_date: 2025-01-01 00:00:00
# Start and end dates scraped from tooltips:  {'end_date': Timestamp('2025-01-01 00:00:00'), 'end_value': 0.9, 'start_date': Timestamp('1959-02-01 00:00:00'), 'start_value': 0.5, 'unit_str': '%'}
# DatetimeIndex(['1959-02-01', '1959-03-01', '1959-04-01', '1959-05-01',
#                '1959-06-01', '1959-07-01', '1959-08-01', '1959-09-01',
#                '1959-10-01', '1959-11-01',
#                ...
#                '2024-04-01', '2024-05-01', '2024-06-01', '2024-07-01',
#                '2024-08-01', '2024-09-01', '2024-10-01', '2024-11-01',
#                '2024-12-01', '2025-01-01'],
#               dtype='datetime64[ns]', length=792, freq='MS')

# %%
scr.get_y_axis(set_global_y_axis=True)   ## Get the y-axis tick positions (pixel co-ordinates) and values, will set the global y-axis attribute since date_span is set to MAX.
# Out:
# INFO - Y-axis values scraped successfully.
# y_heights:  [335.5, 320.5, 269.5, 217.5, 165.5, 114.5, 62.5, 39.5]
# pixheights:  [335.5, 320.5, 269.5, 217.5, 165.5, 114.5, 62.5, 39.5]
# pixheight
# 335.5   -16.0
# 320.5   -14.0
# 269.5    -7.0
# 217.5     0.0
# 165.5     7.0
# 114.5    14.0
# 62.5     21.0
# 39.5     24.0
# Name: ytick_label, dtype: float64

# %%
scr.series_from_chart_soup(set_max_datespan=True) ## Get the full series from the path element of the data trace on the svg chart.
scr.series
# Out:
# INFO - Series path extraction method: Extracting series data from chart soup.
# INFO - Date span: MAX. Chart type: .splineChart, URL: https://tradingeconomics.com/united-states/personal-income.
# 0.000000      213.3125
# 0.000000      213.3125
# 0.467520      212.3975
# 0.779199      211.8375
# 1.124273      211.2175
#                 ...
# 668.803373    214.7875
# 669.137315    214.0500
# 669.482389    213.3125
# 670.000000    210.3625
# 670.000000    210.3625
# Name: Extracted Series, Length: 2374, dtype: float64

# %%
scr.apply_x_index()  ## Apply the x-axis index to the series.
# Out:
# INFO - DateTimeIndex applied to series, series attribute updated.

# %%
scr.series
# Out:
# 1959-02-01    213.3125
# 1959-03-01    211.8375
# 1959-04-01    210.3625
# 1959-05-01    212.5750
# 1959-06-01    212.5750
#                 ...
# 2024-09-01    214.7875
# 2024-10-01    212.5750
# 2024-11-01    214.7875
# 2024-12-01    214.0500
# 2025-01-01    210.3625
# Freq: MS, Name: personal income, Length: 792, dtype: float64

# %% [markdown]
# At this point the value in the data-series are still the pixel co-ordinates in the svg image of the chart.

# %%
scr.plot_series()  ## Plot the series.

# %%
scr.scale_series() ## Scale the series to the y-axis values to convert the pixel co-ordinates to actual data values.
scr.series # View the series data obtained.
# Out:
# INFO - Scale series method:
# unit_per_pix calculated from the y axis ticks: 0.13458915338710736,
# unit_per_pix from axis limits and self.y_axis (probably best way): 0.13513513513513514
# yaxis top tick: 24.0, yaxis bot tick: -16.0
# axis_limits: 335.0, 40.0, y-axis series min & max pixel values: 335.5, 39.5
# Unit per pix forumlation, 24.0, -16.0, 40.0, 296.0, 40.0, 335.0, 0.13513513513513514
# Series crosses zero, x-axis should be at about pixel y-cordinate:  217.5
# 1959-02-01    0.511824
# 1959-03-01    0.711149
# 1959-04-01    0.910473
# 1959-05-01    0.611486
# 1959-06-01    0.611486
#                 ...
# 2024-09-01    0.312500
# 2024-10-01    0.611486
# 2024-11-01    0.312500
# 2024-12-01    0.412162
# 2025-01-01    0.910473
# Freq: MS, Name: personal income, Length: 792, dtype: float64

# %% [markdown]
# The ```scale_series()``` method converts the pixel co-ordinate values to data values.

# %%
scr.plot_series(ann_box_pos=(0, -0.22))  ## Plot the series.

# %%
scr.metadata  ## View the metadata obtained.
# Out:
# {'units': '%',
#  'original_source': 'U.S. Bureau of Economic Analysis',
#  'title': 'United States Personal Income',
#  'indicator': 'personal income',
#  'country': 'united states',
#  'source': 'Trading Economics',
#  'id': 'united-states/personal-income',
#  'description': 'Personal Income refers to the income that persons receive in return for their provision of labor, land, and capital used in current production, plus current transfer receipts less contributions for government social insurance.',
#  'frequency': 'MS',
#  'start_date': '1959-02-01',
#  'end_date': '2025-01-01',
#  'min_value': -12.842905405405403,
#  'max_value': 20.743243243243242,
#  'length': 792}

# %%
scr.save_plot(format="html")  ## Save the plot as an interactive html file.

# %% [markdown]
# ### Alternative scraping methods
#
# Added in v0.3.0. Get the whole series from the tooltip values using javascript. This may turn out to be the best way to do it yet I expect it will run into issues for data series with many points.This has been implemented into the ```scrape_chart``` method as ```method = "tooltips"```.

# %%
scrap = ted.TE_Scraper(use_existing_driver = False, headless = False)  ## Initialize a new TE_scraper object.
scrap.load_page('https://tradingeconomics.com/australia/gdp')
# Out:
# INFO - New firefox webdriver created.
# INFO - Chart types dictionary created successfully: dict_keys(['Column', 'Spline', 'Areaspline', 'Stepline', 'Line', 'Area'])
# INFO - Date span set to: 5Y
# True

# %%
scrap.scrape_metadata()  ## Scrape the metadata for the data series from the page.
# Out:
# INFO -
# Series metadata:
#  {'units': 'USD Billion', 'original_source': 'World Bank', 'title': 'Australia GDP', 'indicator': 'gdp', 'country': 'australia', 'source': 'Trading Economics', 'id': 'australia/gdp'}

# %% [markdown]
# We are using the same ```latest_points_js``` method that is used to get some of the latest data points in order to determine the series frequency. However here we let it keep going and get all of the data points from the date and values that show up on the tooltips as the cursor is dragged across the chart.

# %%
scrap.full_series_fromTooltips(set_max_datespan=True)  ## Get the full series from the tooltips on the chart.
scrap.series
# Out:
# Setting max date span using calendar...
# INFO - Date span set to custom range: 1850-01-01 to 2025-03-14 (using JavaScript)
# INFO - Chart type set to: Spline (using JavaScript)
# INFO - TooltipScraper object initialised successfully.
# INFO - Chart type set to: Spline (using JavaScript)
# INFO - Time taken to select chart type: 0.6471334189991467
# INFO - Time taken to execute JS code: 4.335781779001991
# INFO - Successfully scraped full series from tooltips.
# 1961-01-01      19.68
# 1962-01-01      19.92
# 1963-01-01      21.54
# 1964-01-01      23.80
# 1965-01-01      25.98
#                ...
# 2020-01-01    1330.00
# 2021-01-01    1560.00
# 2022-01-01    1690.00
# 2023-01-01    1730.00
# 2024-01-01    1750.00
# Name: Australia GDP, Length: 64, dtype: float64

# %%
scrap.plot_series(ann_box_pos=(0, -0.22))  ## Plot the series specifying ths series as the on to plot rather than the series attribute of the TE_Scraper.

# %% [markdown]
# - The alternative method has now been implemented as an option in ```scrape_chart``` function. Use method = "tooltips" to use it. Take care as it will miss some points if the history is long and the total datapoints are many. This does indeed miss some datapoints if there are many.
# - If points have been missed you will see frequency: "Unknown/irregular".
# - A new method "mixed" has now been implemented which is the slowest of all yet manages to capture all points from the tooltips using multiple runs at it. That should be the highest accuracy method.
# - **Note:** *Some series on Trading Economics only show dates in the tooltips and not values, these methods will not work for those series. Use "path" instead.*

# %% [markdown]
# ## Get series from tooltips in a single line

# %%
scro = ted.scrape_chart(country="euro-area", id = "gdp-growth-annual", method = "tooltips", use_existing_driver=False, headless=False) ## Using chart id from the url only, country is "united-states" by default.
# Out:
# INFO - New firefox webdriver created.
# INFO - scrape_chart function: Scraping chart at: https://tradingeconomics.com/euro-area/gdp-growth-annual, time: 2025-03-14 12:15:58.611505, method: tooltips
# INFO - Chart types dictionary created successfully: dict_keys(['Column', 'Spline', 'Areaspline', 'Stepline', 'Line', 'Area'])
# INFO - Date span set to: 3Y
# INFO -
# Series metadata:
#  {'units': '%', 'original_source': 'EUROSTAT', 'title': 'Euro Area GDP Annual Growth Rate', 'indicator': 'gdp growth annual', 'country': 'euro area', 'source': 'Trading Economics', 'id': 'euro-area/gdp-growth-annual'}
# INFO - TooltipScraper object initialised successfully.
# INFO - Date span set to custom range: 1850-01-01 to 2025-03-14 (using JavaScript)
# INFO - Chart type set to: Spline (using JavaScript)
# INFO - Chart type set to: Spline (using JavaScript)
# INFO - Time taken to select chart type: 0.6582641979985056
# INFO - Time taken to execute JS code: 4.4223421339993365
# INFO - Successfully scraped full series from tooltips.
# INFO - Successfully scraped full series from tooltips.

# %%
scro.plot_series()  ## Plot the series.

# %% [markdown]
# ## "mixed" method. This gets data from tooltips but also constructs an x_index beforehand.
# This method is selected using ```method = "mixed"``` keyword argument of the ```scrape_chart``` function. This first determines the start & end dates for the full series, calculates frequency and makes the x_index. It then uses multiple runs of the tooltip scraping method to get all of the data at the highest accuracy.

# %%
scrup = ted.scrape_chart(id = "existing-home-sales", method = "mixed", use_existing_driver=False, headless=True) #Using chart id from the url only, country is "united-states" by default.
# Out:
# INFO - New firefox webdriver created.
# INFO - scrape_chart function: Scraping chart at: https://tradingeconomics.com/united-states/existing-home-sales, time: 2025-03-14 12:19:55.265606, method: mixed
# INFO - Chart types dictionary created successfully: dict_keys(['Column', 'Spline', 'Areaspline', 'Stepline', 'Line', 'Area'])
# INFO - Date span set to: 1Y
# INFO -
# Series metadata:
#  {'units': 'Thousand', 'original_source': 'National Association of Realtors', 'title': 'United States Existing Home Sales', 'indicator': 'existing home sales', 'country': 'united states', 'source': 'Trading Economics', 'id': 'united-states/existing-home-sales'}
# INFO - Chart type set to: Spline (using JavaScript)
# Using selenium and tooltip scraping to construct the date time index for the time-series, this'll take a bit...
# INFO - Time taken to select chart type: 0.6961485919964616
# INFO - Time taken to execute JS code: 2.727702214004239
# Frequency of time-series:  MS
# INFO - Date span set to custom range: 1850-01-01 to 2025-03-14 (using JavaScript)
# INFO - Chart type set to: Spline (using JavaScript)
# INFO - Successfully retrieved first/last dates.
# Converted end_date: 2025-01-01 00:00:00
# Retrying start_end extraction...
# INFO - Successfully retrieved first/last dates.
# INFO - Start and end values scraped from tooltips:
# {'end_date': Timestamp('2025-01-01 00:00:00'), 'end_value': 4080.0, 'start_date': Timestamp('1968-01-01 00:00:00'), 'start_value': 1420.0, 'unit_str': 'Thousand'}
# INFO - DateTimeIndex created successfully for the time-series.
# INFO -  Using mixed scraping approach, slowest, highest accuracy. Splitting x_index into subIndexes        Total points: 685, Max chunk size: 500, Number of chunks: 2, remainder: 1
# INFO - x_index Start date: 1968-01-01 00:00:00, End date: 2025-01-01 00:00:00
# INFO - SubIndex 0: 342 points, from 1968-01-01 00:00:00 to 1996-06-01 00:00:00, frequency: MS
# Converted start_date: 1968-01-01 00:00:00
# Converted end_date: 2025-01-01 00:00:00
# Start and end dates scraped from tooltips:  {'end_date': Timestamp('2025-01-01 00:00:00'), 'end_value': 4080.0, 'start_date': Timestamp('1968-01-01 00:00:00'), 'start_value': 1420.0, 'unit_str': 'Thousand'}
# INFO - Date span set to custom range: 1968-01-01 to 1996-06-01 (using JavaScript)
# INFO - Chart type set to: Spline (using JavaScript)
# INFO - Chart type set to: Spline (using JavaScript)
# INFO - Time taken to select chart type: 0.6762937520034029
# INFO - Time taken to execute JS code: 4.217832076996274
# INFO - SubIndex 1: 343 points, from 1996-07-01 00:00:00 to 2025-01-01 00:00:00, frequency: MS
# INFO - Date span set to custom range: 1996-07-01 to 2025-03-14 (using JavaScript)
# INFO - Chart type set to: Spline (using JavaScript)
# INFO - Chart type set to: Spline (using JavaScript)
# INFO - Time taken to select chart type: 0.6704935400048271
# INFO - Time taken to execute JS code: 4.027445242005342
# INFO - Successfully scraped full series from tooltips.
# INFO - Successfully scraped full series using mixed method.

# %%
scrup.plot_series()  ## Plot the series.

# %% [markdown]
# ### The Best Scraping Method: ```highcharts_api```
#
# This method is the fastest and the most accurate. It is the default.

# %%
bestway = ted.scrape_chart(indicator = "consumer-confidence", method = "highcharts_api") ## method = "highcharts_api" is unnecessary as it is the default value anyhow. Country is "united-states" by default.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 bestway = ted.scrape_chart(indicator = "consumer-confidence", method = "highcharts_api")
#
# NameError: name 'ted' is not defined
